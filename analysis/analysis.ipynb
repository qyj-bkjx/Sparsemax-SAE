# %%
from datasets import load_dataset
from utils import DATASET_INFO, get_stats_scatter_plot, load_stats, plot_ref_images
import kaleido

# %%
dataset_name = "imagenet"
save_directory = f"your data path"

stats = load_stats(save_directory, device="cpu")

# %%
# you might need to install packages to run this
# $ pip install -U kaleido
# $ conda install nbformat
get_stats_scatter_plot(stats, save_directory=save_directory)

# %%
dataset = load_dataset(**DATASET_INFO[dataset_name])
dataset = dataset.shuffle(seed=1)

# %%
latent_idx = 10066  # any index within range(0, 49152)
plot_ref_images(stats, dataset, latent_idx=latent_idx, plot_top_k=10)
